# %% [markdown]
# ## Transformacion de datos

# %%
# !dir

# %%
import pandas as pd

headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

file_path = "auto.csv"

df = pd.read_csv(file_path, names=headers)

# %%
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# ejercicio1
# crear un df2 en donde esten los campos "symboling" "normalized-losses" "make","fuel-type","price"

# %%
df2 = df[["symboling","normalized-losses","make","fuel-type","price"]]
df2.head()
# Out:
#    symboling normalized-losses         make fuel-type  price
# 0          3                 ?  alfa-romero       gas  13495
# 1          3                 ?  alfa-romero       gas  16500
# 2          1                 ?  alfa-romero       gas  16500
# 3          2               164         audi       gas  13950
# 4          2               164         audi       gas  17450

# %% [markdown]
# identificamos datos perdidos

# %%
nro_price_validate = df['price'].loc[df['price'] !='?'].count()
nro_price_validate
# Out:
# 201

# %%
nro_length_validate = df['length'].loc[df['length'] !='?'].count()
nro_length_validate
# Out:
# 205

# %%
nro_normalized_losses_validate = df['normalized-losses'].loc[df['normalized-losses'] !='?'].count()
nro_normalized_losses_validate
# Out:
# 164

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Se obtiene las variables con datos perdidos

missing_data = df.isnull()
missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False              False  False      False       False         False
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
# 5      False              False  False      False       False         False
# 6      False              False  False      False       False         False
# 7      False              False  False      False       False         False
# 8      False              False  False      False       False         False
# 9      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Contar datos perdidos por columnas

for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %% [markdown]
# reemplazo de datos faltantes por la media

# %%
# bore
COLUMNA=0
avg_bore=df['bore'].astype('float').mean(axis=COLUMNA)
avg_bore = round(avg_bore,4)
print("Average of bore:", avg_bore)
df["bore"].replace(np.nan, avg_bore, inplace=True)
# Out:
# Average of bore: 3.3298

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# Ejercicio : reemplazar la media para los campos
# "normalized-losses": 41 datos perdidos, se reemplazar por la media
# "stroke": 4 datos perdidos, se reemplazar por la media
# "horsepower": 2 datos perdidos, se reemplazar por la media
# "peak-rpm": 2 datos perdidos, se reemplazar por la media

# %%
# normalized-losses
COLUMNA=0
avg_normalized=df['normalized-losses'].astype('float').mean(axis=COLUMNA)
avg_normalized = round(avg_normalized,4)
print("Average normalized-losses:", avg_normalized)
df["normalized-losses"].replace(np.nan, avg_normalized, inplace=True)
# Out:
# Average normalized-losses: 122.0

# %%
# stroke
COLUMNA=0
avg_stroke=df['stroke'].astype('float').mean(axis=COLUMNA)
avg_stroke = round(avg_stroke,4)
print("Average stroke:", avg_stroke)
df["stroke"].replace(np.nan, avg_stroke, inplace=True)
# Out:
# Average stroke: 3.2554

# %%
# horsepower
COLUMNA=0
avg_horsepower=df['horsepower'].astype('float').mean(axis=COLUMNA)
avg_horsepower = round(avg_horsepower,4)
print("Average horsepower:", avg_horsepower)
df["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# Average horsepower: 104.2562

# %%
# peak-rpm
COLUMNA=0
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=COLUMNA)
avg_peakrpm = round(avg_peakrpm,4)
print("Average peak-rpm:", avg_peakrpm)
df["peak-rpm"].replace(np.nan,avg_peakrpm, inplace=True)
# Out:
# Average peak-rpm: 5125.3695

# %%
missing_data = df.isnull()
# Contar datos perdidos por columnas
for column in df.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    205
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# ...

# %% [markdown]
# Reemplazo de datos faltantes por la moda ( Reemplazo de datos faltantes para variables categoricas )

# %%
# Buscando la moda
df["num-of-doors"].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
# Otra manera de visualizar moda
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
# Se reemplaza con la moda
df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %% [markdown]
# Eliminación de datos faltantes para la variable dependientes

# %%
df.dropna(subset=["price"], axis=0, inplace = True)

# %%
missing_data = df.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    201
# Name: symboling, dtype: int64
#
# normalized-losses
# False    201
# Name: normalized-losses, dtype: int64
#
# make
# False    201
# Name: make, dtype: int64
#
# fuel-type
# False    201
# Name: fuel-type, dtype: int64
#
# aspiration
# False    201
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    201
# Name: num-of-doors, dtype: int64
#
# body-style
# False    201
# Name: body-style, dtype: int64
#
# drive-wheels
# False    201
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    201
# Name: engine-location, dtype: int64
#
# wheel-base
# False    201
# Name: wheel-base, dtype: int64
#
# length
# False    201
# Name: length, dtype: int64
#
# width
# False    201
# Name: width, dtype: int64
#
# height
# False    201
# Name: height, dtype: int64
#
# curb-weight
# False    201
# Name: curb-weight, dtype: int64
#
# engine-type
# False    201
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    201
# ...

# %% [markdown]
# Correción de formato de datos

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# cambiar price de tipo objets a float

# %%
df["price"] = df["price"].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Ejercicio , cambiar el tipo de datos de las variables predictoras:
# "bore", "stroke", "peak-rpm" a float
# "normalized-losses" a int

# %%
df["bore"] = df["bore"].astype("float")
df["stroke"] = df["stroke"].astype("float")
df["peak-rpm"] = df["peak-rpm"].astype("float")
df["normalized-losses"] = df["price"].astype("int")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Estandarizacion

# %%
df.head(1)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              13495  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
#
# [1 rows x 26 columns]

# %%
# Convirtiendo mpg a km : (235 dividido por mpg)
df['city-km'] = round(235/df["city-mpg"],3)

# mostramos datos
df[['city-mpg','city-km']].head()
# Out:
#    city-mpg  city-km
# 0        21   11.190
# 1        21   11.190
# 2        19   12.368
# 3        24    9.792
# 4        18   13.056

# %% [markdown]
# Ejercicio , transformar la variables predictora "highway-mpg" a kilometros en la nueva variable predictora "highway-km"

# %%
# Convirtiendo mpg a km : (235 dividido por mpg)
df['highway-km'] = round(235/df["highway-mpg"],3)

# mostramos datos
df[['highway-mpg','highway-km']].head()
# Out:
#    highway-mpg  highway-km
# 0           27       8.704
# 1           27       8.704
# 2           26       9.038
# 3           30       7.833
# 4           22      10.682

# %%
# replace (original value) by (original value)/(maximum value)
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()
df['height'] = df['height']/df['width'].max()
# mostramos datos
df[['length','width','height']].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# Ejercicio , normalizar la variable predictora "height"

# %%
# replace (original value) by (original value)/(maximum value)
df['height'] = df['height']/df['height'].max()
df[['height']].head()
# Out:
#      height
# 0  0.816054
# 1  0.816054
# 2  0.876254
# 3  0.908027
# 4  0.908027

# %% [markdown]
# Binning

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(df["horsepower"])

# set x , y labels y titulo
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("nro. veces")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
np.linspace(10,20,2)
# Out:
# array([10., 20.])

# %%
np.linspace(10,20,3)
# Out:
# array([10., 15., 20.])

# %%
np.linspace(10,20,4)
# Out:
# array([10.        , 13.33333333, 16.66666667, 20.        ])

# %%
# Genera puntos de corte 
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Bajo', 'Medio', 'Alto']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head()
# Out:
#    horsepower horsepower-binned
# 0         111              Bajo
# 1         111              Bajo
# 2         154             Medio
# 3         102              Bajo
# 4         115              Bajo

# %%
df["horsepower-binned"].value_counts()
# Out:
# Bajo     153
# Medio     43
# Alto       5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("nro. veces")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# variables dummy

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-km', 'highway-km', 'horsepower-binned'],
#       dtype='object')

# %%
df["fuel-type"].head()
# Out:
# 0    gas
# 1    gas
# 2    gas
# 3    gas
# 4    gas
# Name: fuel-type, dtype: object

# %%
df["fuel-type"].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel-type, dtype: int64

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head(100)
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 98        0    1
# 99        0    1
# 100       0    1
# 101       0    1
# 102       0    1
#
# [100 rows x 2 columns]

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
df = pd.concat([df, dummy_variable_1], axis=1)

# %%
df[["fuel-type","fuel-type-gas","fuel-type-diesel"]].head()
# Out:
#   fuel-type  fuel-type-gas  fuel-type-diesel
# 0       gas              1                 0
# 1       gas              1                 0
# 2       gas              1                 0
# 3       gas              1                 0
# 4       gas              1                 0

# %%
### Ejercicio : crear variables dummy para "aspiration" con :  "std" to 0, while "turbo" to 1.

# %%
df["aspiration"].head()
# Out:
# 0    std
# 1    std
# 2    std
# 3    std
# 4    std
# Name: aspiration, dtype: object

# %%
df["aspiration"].value_counts()
# Out:
# std      165
# turbo     36
# Name: aspiration, dtype: int64

# %%
dummy_variable_2 = pd.get_dummies(df["aspiration"])
dummy_variable_2.head(20)
# Out:
#     std  turbo
# 0     1      0
# 1     1      0
# 2     1      0
# 3     1      0
# 4     1      0
# 5     1      0
# 6     1      0
# 7     1      0
# 8     0      1
# 10    1      0
# 11    1      0
# 12    1      0
# 13    1      0
# 14    1      0
# 15    1      0
# 16    1      0
# 17    1      0
# 18    1      0
# 19    1      0
# 20    1      0

# %%
df.to_csv('datos_limpios_df.csv')

# %%
# !dir
# Out:
#  El volumen de la unidad C es Windows 10
#  El n£mero de serie del volumen es: A24A-65DC
#
#  Directorio de C:\Users\PCC-DOMINGO\clase09
#
# 12/01/2020  13:12    <DIR>          .
# 12/01/2020  13:12    <DIR>          ..
# 12/01/2020  09:48    <DIR>          .ipynb_checkpoints
# 12/01/2020  05:43            24,916 auto.csv
# 12/01/2020  13:12            39,304 datos_limpios_df.csv
# 12/01/2020  13:11           118,637 session03_clase09.ipynb
# 12/01/2020  05:43            82,076 transformacion_datos.ipynb
#                4 archivos        264,933 bytes
#                3 dirs  382,348,865,536 bytes libres
